# %%
import pandas as pd

# %%
df_covid19 = pd.read_csv("./covid19_timeseries.csv")
df_worldometer  = pd.read_csv("./worldometer.csv")

# %%
df_covid19.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df_covid19.drop(columns=["Province/State"], inplace=True)

# %%
df_covid19["uuid"] = [i for i in range(1, df_covid19.shape[0] + 1)]

# %%
df_covid19.head()
# Out:
#   Country/Region       Lat       Long        Date  Confirmed  Deaths  \
# 0    Afghanistan  33.93911  67.709953  2020-01-22          0       0
# 1        Albania  41.15330  20.168300  2020-01-22          0       0
# 2        Algeria  28.03390   1.659600  2020-01-22          0       0
# 3        Andorra  42.50630   1.521800  2020-01-22          0       0
# 4         Angola -11.20270  17.873900  2020-01-22          0       0
#
#    Recovered  Active             WHO Region  uuid
# 0          0       0  Eastern Mediterranean     1
# 1          0       0                 Europe     2
# 2          0       0                 Africa     3
# 3          0       0                 Europe     4
# 4          0       0                 Africa     5

# %%
df_worldometer[50:100]
# Out:
#     Rank CCA3   Country/Territory           Capital      Continent  \
# 50    88  CZE      Czech Republic            Prague         Europe
# 51   115  DNK             Denmark        Copenhagen         Europe
# 52   160  DJI            Djibouti          Djibouti         Africa
# 53   204  DMA            Dominica            Roseau  North America
# 54    84  DOM  Dominican Republic     Santo Domingo  North America
# 55    15  COD            DR Congo          Kinshasa         Africa
# 56    67  ECU             Ecuador             Quito  South America
# 57    14  EGY               Egypt             Cairo         Africa
# 58   112  SLV         El Salvador      San Salvador  North America
# 59   152  GNQ   Equatorial Guinea            Malabo         Africa
# 60   132  ERI             Eritrea            Asmara         Africa
# 61   156  EST             Estonia           Tallinn         Europe
# 62   159  SWZ            Eswatini           Mbabane         Africa
# ...

# %%
df_covid19.to_csv("./cleaned_data/covid19_timeseries.csv", index=False)
df_worldometer.to_csv("./cleaned_data/worldometer.csv", index=False)
